# %%
import numpy as np 
import pandas as pd
import seaborn as sns
sns.reset_defaults
sns.set_style(style='darkgrid')
sns.set_context(context='notebook')
import matplotlib.pyplot as plt
#plt.style.use('ggplot')
plt.rcParams["patch.force_edgecolor"] = True
plt.rcParams['figure.figsize'] = (20.0, 10.0)
font = {'size'   : 20}
plt.rc('font', **font)
plt.ion()
# %matplotlib inline

# %% [markdown]
# Observations: the large majority of students only took one module, about 10k instances of "unregistering"

# %% [markdown]
# To Do: does registering early or late have an effect on success?

# %%
reg_df = pd.read_csv('../data/raw/studentRegistrations.csv')

# %%
reg_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32593 entries, 0 to 32592
# Data columns (total 5 columns):
# code_module            32593 non-null object
# code_presentation      32593 non-null object
# id_student             32593 non-null int64
# date_registration      32548 non-null float64
# date_unregistration    10072 non-null float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.2+ MB

# %%
reg_df.sample(10)
# Out:
#       code_module code_presentation  id_student  date_registration  \
# 4962          BBB             2014B      388041              -79.0
# 14945         DDD             2013J      489150              -38.0
# 5495          BBB             2014B      608060              -86.0
# 13831         DDD             2013B      538251              -22.0
# 25763         FFF             2013J      604416              -35.0
# 7796          BBB             2014J      676604             -108.0
# 21322         EEE             2014J      556450              -56.0
# 8830          CCC             2014B      277577              -26.0
# 18352         DDD             2014J      626546             -120.0
# 14579         DDD             2013J      274712             -150.0
#
#        date_unregistration
# 4962                  -8.0
# 14945                  0.0
# 5495                  -7.0
# 13831                  NaN
# 25763                  NaN
# 7796                   NaN
# 21322                  NaN
# 8830                 -23.0
# 18352                111.0
# 14579                  NaN

# %%
sns.lmplot(x='date_registration', y='date_unregistration', data=reg_df.dropna(), size=8)
# Out:
# /Users/jeremymiller/anaconda3/lib/python3.6/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
by_student = reg.groupby('id_student').count()[['code_module']]

# %%
by_student['code_module'].value_counts()
# Out:
# 1    25247
# 2     3293
# 3      221
# 4       23
# 5        1
# Name: code_module, dtype: int64

# %%
reg['code_module'].value_counts()
# Out:
# BBB    7909
# FFF    7762
# DDD    6272
# CCC    4434
# EEE    2934
# GGG    2534
# AAA     748
# Name: code_module, dtype: int64

# %%
reg.dropna(axis=0).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10033 entries, 2 to 32591
# Data columns (total 5 columns):
# code_module            10033 non-null object
# code_presentation      10033 non-null object
# id_student             10033 non-null int64
# date_registration      10033 non-null float64
# date_unregistration    10033 non-null float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 470.3+ KB
